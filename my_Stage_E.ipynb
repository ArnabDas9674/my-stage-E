# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
from bs4 import BeautifulSoup
url1 = 'https://investors.coca-colacompany.com/news-events/press-releases/detail/981/coca-cola-reports-strong-growth-in-fourth-quarter-and-full'
r1 = requests.get(url1)
soup = BeautifulSoup(r1.text, 'lxml')
soup.find('ul', class_="bwlistdisc").find('li').text
# Out:
# '\nRevenues: Net revenues grew 16% to $9.1 billion for the quarter and 9% to $37.3 billion for the year. Organic revenues (non-GAAP) grew 7% for the quarter and 6% for the year. Revenue growth for the quarter was driven by concentrate sales growth of 2% and price/mix growth of 5%. The quarter included one additional day, which resulted in an approximate 1-point benefit to revenue growth. Revenue growth for the year was driven by concentrate sales growth of 1% and price/mix growth of 5%.'

# %%
nr19=37.3

# %%
url3 = 'https://www.coca-colacompany.com/media-center/the-coca-cola-company-reports-operating-results-q4-2017'
r3 = requests.get(url3)
soup = BeautifulSoup(r3.text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html lang="en-US">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Fourth Quarter 2017 Operating Results Strong | Press Release
#   </title>
#   <meta content="The Coca-Cola Company Reports Strong Operating Results for Fourth Quarter and Full Year 2017; Achieves or Exceeds the Company's Full Year Guidance. Read this press release from The Coca-Cola Company." name="description"/>
#   <meta content="article-page" name="template"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="1.550.0" name="cepVersion"/>
#   <meta content="2018-02-16T05:00:00Z" name="publicationDate"/>
#   <meta content="Media Center - Article" name="contentType"/>
#   <link href="https://www.coca-colacompany.com/media-center/the-coca-cola-company-reports-operating-results-q4-2017" rel="canonical"/>
#   <!-- OneTrust  Cookies Consent Notice start for coca-colacompany.com  -->
# ...

# %%
soup.find('div', id="text-18098093cd" , class_="cmp-text").find('p')
# Out:
# <p style="	margin-left: 40.0px;
# "><b>- Revenues:Â </b>Net revenues declined 20% to $7.5 billion for the quarter and declined 15% to $35.4 billion for the year, impacted by headwinds of 26% and 17%, respectively, from the ongoing refranchising of bottling territories. Organic revenues (non-GAAP) grew 6% for the quarter, driven by price/mix growth of 4% and concentrate sales growth of 1%. The quarter included one additional day, which equated to an approximate one point benefit to organic revenue (non-GAAP) growth. For the year, organic revenues (non-GAAP) grew 3%, driven by price/mix growth of 3%.Â <br/>
# </p>

# %%
nr17=35.4
nr16=41.86

# %%
url4 = 'https://companiesmarketcap.com/coca-cola/revenue/'
r4 = requests.get(url4)
BeautifulSoup(r4.text, 'lxml')
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# <title>Coca-Cola (KO) - Revenue</title>
# <meta charset="utf-8"/>
# <link href="https://companiesmarketcap.com/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <link href="/img/icons/apple-icon-57x57.png" rel="apple-touch-icon" sizes="57x57"/>
# <link href="/img/icons/apple-icon-60x60.png" rel="apple-touch-icon" sizes="60x60"/>
# <link href="/img/icons/apple-icon-72x72.png" rel="apple-touch-icon" sizes="72x72"/>
# <link href="/img/icons/apple-icon-76x76.png" rel="apple-touch-icon" sizes="76x76"/>
# <link href="/img/icons/apple-icon-114x114.png" rel="apple-touch-icon" sizes="114x114"/>
# <link href="/img/icons/apple-icon-120x120.png" rel="apple-touch-icon" sizes="120x120"/>
# <link href="/img/icons/apple-icon-144x144.png" rel="apple-touch-icon" sizes="144x144"/>
# <link href="/img/icons/apple-icon-152x152.png" rel="apple-touch-icon" sizes="152x152"/>
# ...

# %%
nr15=44.29
nr18=31.9

# %%
url5 = 'https://en.wikipedia.org/wiki/The_Coca-Cola_Company'
r5 = requests.get(url5)
soup = BeautifulSoup(r5.text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-enabled vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-disabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    The Coca-Cola Company - Wikipedia
#   </title>
#   <script>
# ...

# %%
soup.find('table', class_="wikitable float-left")
# Out:
# <table class="wikitable float-left" style="text-align: right;">
# <tbody><tr>
# <th>Year
# </th>
# <th>Revenue<br/>in million US$
# </th>
# <th>Net income<br/>in million US$
# </th>
# <th>Price per Share<br/>in USD<sup class="reference" id="cite_ref-42"><a href="#cite_note-42">[42]</a></sup>
# </th>
# <th>Employees
# </th></tr>
# <tr>
# <td>2000<sup class="reference" id="cite_ref-:4_43-0"><a href="#cite_note-:4-43">[43]</a></sup>
# </td>
# <td>17,354
# </td>
# <td>2,177
# </td>
# <td>14.41
# </td>
# <td>
# </td></tr>
# <tr>
# <td>2001<sup class="reference" id="cite_ref-:4_43-1"><a href="#cite_note-:4-43">[43]</a></sup>
# </td>
# <td>17,545
# </td>
# <td>3,969
# </td>
# <td>12.83
# </td>
# <td>
# </td></tr>
# <tr>
# <td>2002<sup class="reference" id="cite_ref-:4_43-2"><a href="#cite_note-:4-43">[43]</a></sup>
# </td>
# <td>19,394
# </td>
# <td>3,050
# </td>
# <td>13.32
# </td>
# <td>
# </td></tr>
# <tr>
# ...

# %%
nr14=45.99
nr13=46.85
nr12=48.07
nr11=46.54
nr10=35.11
nr9=30.99

# %%
df = {'Year': ['2009', '2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018', '2019'], 'Revenue (in billion)': [nr9, nr10, nr11, nr12, nr13, nr14, nr15, nr16, nr17, nr18, nr19]}
df = pd.DataFrame(df)
df
# Out:
#     Year  Revenue (in billion)
# 0   2009                 30.99
# 1   2010                 35.11
# 2   2011                 46.54
# 3   2012                 48.07
# 4   2013                 46.85
# 5   2014                 45.99
# 6   2015                 44.29
# 7   2016                 41.86
# 8   2017                 35.40
# 9   2018                 31.90
# 10  2019                 37.30

# %%
import seaborn as sns
sns.barplot(x='Year', y='Revenue (in billion)', data=df)
plt.xlabel('Year')
plt.ylabel('Revenue (in billion)')
plt.title('Coca Cola Company Revenue Over Time')
# Out:
# Text(0.5, 1.0, 'Coca Cola Company Revenue Over Time')

# %%
url6 = 'https://investors.coca-colacompany.com/stock-information/year-end-market-values'
r6 = requests.get(url6)
soup = BeautifulSoup(r6.text, 'lxml')
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <!-- OneTrust Cookies Consent Notice start for investors.coca-colacompany.com -->
#   <script charset="UTF-8" data-domain-script="ebbed70e-0f06-447c-88e2-911b43af0a09" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    function OptanonWrapper () {
#             if (OneTrust.IsAlertBoxClosed() === false) {
#               var prefpc = document.getElementById("onetrust-pc-sdk");
#               var filter = document.getElementsByClassName("onetrust-pc-dark-filter")[0];
#               var style = document.createElement('style');
#               style.innerHTML = '#onetrust-banner-sdk {display:none !important}';
#               document.head.appendChild(style);
#               prefpc.style = 'display: block !important; animation: example1 3s linear';
#               filter.style = 'display: block !important';
#             }
# ...

# %%
soup.find('table', class_="content-table")
# Out:
# <table class="content-table">
# <thead>
# <tr>
# <th>Year</th>
# <th>Closing Price<br/>at Year-End</th>
# <th>Annual Dividends<br/>Per Share</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td>2022</td>
# <td>$63.61</td>
# <td>$1.76</td>
# </tr>
# <tr>
# <td>2021</td>
# <td>$59.21</td>
# <td>$1.68</td>
# </tr>
# <tr>
# <td>2020</td>
# <td>$54.84</td>
# <td>$1.64</td>
# </tr>
# <tr>
# <td>2019</td>
# <td>$55.35</td>
# <td>$1.60</td>
# </tr>
# <tr>
# <td>2018</td>
# <td>$47.35</td>
# <td>$1.56</td>
# </tr>
# <tr>
# <td>2017</td>
# <td>$45.88</td>
# <td>$1.48</td>
# </tr>
# <tr>
# <td>2016</td>
# <td>$41.46</td>
# <td>$1.40</td>
# </tr>
# <tr>
# <td>2015</td>
# <td>$42.96</td>
# <td>$1.32</td>
# </tr>
# <tr>
# <td>2014</td>
# <td>$42.22</td>
# <td>$1.22</td>
# </tr>
# <tr>
# <td>2013</td>
# <td>$41.31</td>
# <td>$1.12</td>
# </tr>
# <tr>
# <td colspan="3" style="text-align: center;">2:1 Split Record Date 7/27/12</td>
# </tr>
# <tr>
# <td>2012</td>
# <td>$36.25</td>
# <td>$1.02</td>
# </tr>
# ...

# %%
spd = {'Year':['2009','2010','2011','2012','2013','2014','2015', '2016', '2017', '2018', '2019'], 'Stock Price at Year end (in $)':[57, 65.77, 69.97, 36.25, 41.31, 42.22, 42.96, 41.46, 45.88, 47.35, 55.35]}
spd = pd.DataFrame(spd)
spd
# Out:
#     Year  Stock Price at Year end (in $)
# 0   2009                           57.00
# 1   2010                           65.77
# 2   2011                           69.97
# 3   2012                           36.25
# 4   2013                           41.31
# 5   2014                           42.22
# 6   2015                           42.96
# 7   2016                           41.46
# 8   2017                           45.88
# 9   2018                           47.35
# 10  2019                           55.35

# %%
sns.barplot(x='Year', y='Stock Price at Year end (in $)', data=spd)
plt.xlabel('Year')
plt.ylabel('Stock Price at Year end (in $)')
plt.title('Coca Cola Company Stock Price Over Time')
# Out:
# Text(0.5, 1.0, 'Coca Cola Company Stock Price Over Time')
